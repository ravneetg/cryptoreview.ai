# %%
import pandas as pd

# %%
df_news = pd.read_csv("./data/news_signals.csv.gz", compression='gzip')
print(df_news.shape)
df_news.sample(10)
# Out:
# (2427131, 5)
#         ticker         datetime_hour                signal  \
# 1970969   DOGE  2022-07-27T20:00:00Z          news_pos_avg
# 651976     LTC  2020-07-02T21:00:00Z  news_num_of_articles
# 999045     XLM  2021-03-20T20:00:00Z    news_sentiment_avg
# 195637     BTC  2020-07-04T00:00:00Z  news_sentiment_index
# 917620    USDT  2020-09-12T13:00:00Z    news_sentiment_avg
# 2037677   ALGO  2022-08-25T12:00:00Z  news_num_of_articles
# 1390320   DOGE  2021-10-31T11:00:00Z          news_neg_avg
# 1730601    BTC  2022-04-06T15:00:00Z  news_num_of_articles
# 517726      HT  2020-01-10T04:00:00Z  news_sentiment_index
# 470067     ETH  2020-09-14T03:00:00Z        news_neg_count
#
#          value_1hr_interval  value_day
# 1970969            0.947567   0.927172
# 651976             1.000000  16.000000
# 999045             0.942700   0.902676
# 195637             1.691761   1.265280
# 917620            -0.571900  -0.729260
# 2037677            1.000000   4.000000
# ...

# %%
df_reddit = pd.read_csv("./data/reddit_signals.csv.gz", compression='gzip')
print(df_reddit.shape)
df_reddit.sample(10)
# Out:
# (1927714, 5)
# /home/blue/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         ticker         datetime_hour                       signal  \
# 978895     BTC  2021-08-30T04:00:00Z  reddit_submission_sentiment
# 1322082    ETH  2022-03-13T18:00:00Z     reddit_comment_sentiment
# 1471116    XTZ  2022-05-30T14:00:00Z  reddit_comment_num_comments
# 411984     BTC  2020-09-14T20:00:00Z  reddit_comment_num_comments
# 894867     ETH  2021-07-19T13:00:00Z     reddit_comment_sentiment
# 428833     BTC  2021-06-13T03:00:00Z     reddit_comment_sentiment
# 1909827    XRP  2023-04-17T23:00:00Z  reddit_submission_sentiment
# 565082     TRX  2021-04-06T04:00:00Z  reddit_comment_num_comments
# 325712     ADA  2020-03-13T00:00:00Z     reddit_comment_sentiment
# ...
