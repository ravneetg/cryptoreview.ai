# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./tesla_data_experiment.csv")
print(df.shape)
df.head()
# Out:
# (32, 11)
#   published_date  sentiment  num_of_articles    open      high       low  \
# 0     2020-12-14      85.94              153  619.00  642.7499  610.2001
# 1     2020-12-15      89.63              154  643.28  646.9000  623.8000
# 2     2020-12-16      87.83              139  628.23  632.5000  605.0000
# 3     2020-12-17      87.85              146  628.19  658.8200  619.5000
# 4     2020-12-18      86.75              172  668.90  695.0000  628.5400
#
#     close       volume  %chg_openclose  %chg_openclose_lag1  \
# 0  639.83   52040649.0            3.37                 0.00
# 1  633.25   45223559.0           -1.56                 3.37
# 2  622.77   42095813.0           -0.87                -1.56
# 3  655.90   56270144.0            4.41                -0.87
# 4  695.00  222126194.0            3.90                 4.41
#
#    %chg_openclose_lead1
# 0                 -1.56
# 1                 -0.87
# 2                  4.41
# 3                  3.90
# 4                   NaN

# %%
corr = df.corr(method='pearson')
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_e3862_row0_col0,#T_e3862_row1_col1,#T_e3862_row2_col2,#T_e3862_row3_col3,#T_e3862_row4_col4,#T_e3862_row5_col5,#T_e3862_row6_col6,#T_e3862_row7_col7,#T_e3862_row8_col8,#T_e3862_row9_col9{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_e3862_row0_col1,#T_e3862_row0_col2,#T_e3862_row0_col3,#T_e3862_row0_col4,#T_e3862_row0_col5,#T_e3862_row0_col7,#T_e3862_row4_col0,#T_e3862_row5_col0,#T_e3862_row8_col9,#T_e3862_row9_col6,#T_e3862_row9_col8{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_e3862_row0_col6{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_e3862_row0_col8{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_e3862_row0_col9{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_e3862_row1_col0{
#             background-color:  #506bda;
# ...
